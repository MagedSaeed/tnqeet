# %%
from tqdm.auto import tqdm
from tnqeet.data import train_dataset

# %%
lengths = []
for example in tqdm(train_dataset):
    lengths.append(len(example["text"]))
sum(lengths) / len(lengths)
# Out:
#   0%|          | 0/3588620 [00:00<?, ?it/s]
# 726.0251453204853
