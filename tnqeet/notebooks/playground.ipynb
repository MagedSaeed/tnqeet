# %%
from tnqeet import remove_dots

# %%
text = 'بسم الله الرحمن الرحيم'
remove_dots(text)
# Out:
# 'ٮسم الله الرحمں الرحىم'

# %%
text = 'هذا نص بريء ويرجع إليه حين الخلاف، يحيل ولا ينطق، وذو قوة وجأش'
remove_dots(text)
# Out:
# 'هدا ںص ٮرىء وىرحع الىه حىں الحلاڡ، ىحىل ولا ىںطٯ، ودو ٯوه وحاس'
