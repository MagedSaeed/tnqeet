# %%
import os
from tqdm.auto import tqdm
from tnqeet.data import train_dataset, test_dataset

# %%
def to_chars(text):
    chars = list()
    for c in text:
        if c.isspace():
            chars.append('<SPACE>')
        else:
            chars.append(c)
    chars = ' '.join(chars)
    return chars

# %%
def write_dataset_to_file(dataset, filename):
    with open(filename, "w", encoding="utf-8") as f:
        for item in tqdm(dataset, desc=f"Writing {filename}"):
            f.write(to_chars(item['text'].strip()) + '\n')

# %%
# !mkdir -p tmp

# %%
if not os.path.exists("tmp/ngrams_train_dataset.txt"):
    write_dataset_to_file(train_dataset, "tmp/ngrams_train_dataset.txt")

# %%
if not os.path.exists("tmp/ngrams_test_dataset.txt"):
    write_dataset_to_file(test_dataset, "tmp/ngrams_test_dataset.txt")

# %%
def train_lm(ngram, overwrite=False):
    if not overwrite and os.path.exists(f"tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.binary"):
        print(f"Language model for ngram {ngram} already exists. Skipping training.")
        return
    # !mkdir -p tnqeet/dotting_models/ngrams/trained_models
    if ngram > 2:
        # !kenlm/build/bin/lmplz -o {ngram} --discount_fallback --text tmp/ngrams_train_dataset.txt --arpa tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.arpa --prune 0 0 1
    else:
        # !kenlm/build/bin/lmplz -o {ngram} --discount_fallback --text tmp/ngrams_train_dataset.txt --arpa tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.arpa
    # !kenlm/build/bin/build_binary tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.arpa tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.binary
    # drop the arpa file to save space
    # !rm tnqeet/dotting_models/ngrams/trained_models/ngrams_{ngram}.arpa

# %%
def get_perplexity_and_OOVs(model_path):
    # calculate and dump to a file
    model_name = model_path.split('/')[-1].removesuffix('.binary').removeprefix('.arpa')
    # !mkdir -p tnqeet/dotting_models/ngrams/test_results_kenlm_output
    # !kenlm/build/bin/query "{model_path}" < tmp/ngrams_test_dataset.txt > tnqeet/dotting_models/ngrams/test_results_kenlm_output/"{model_name}".txt
    
    print('model name is:', model_name)
    with open(
        f"tnqeet/dotting_models/ngrams/test_results_kenlm_output/{model_name}.txt",
        "r",
        encoding="utf-8",
        ) as f:
        lines = f.read().splitlines()

    # collect
    perplexity_with_OOVs_line = lines[-4]
    perplexity_without_OOVs_line = lines[-3]
    counts_of_OOVs_line = lines[-2]

    perplexity_with_OOVs = float(perplexity_with_OOVs_line.split("Perplexity including OOVs:")[-1].strip())
    perplexity_without_OOVs = float(perplexity_without_OOVs_line.split("Perplexity excluding OOVs:")[-1].strip())
    counts_of_OOVs = int(counts_of_OOVs_line.split("OOVs:")[-1].strip())

    return perplexity_with_OOVs, perplexity_without_OOVs, counts_of_OOVs

# %%
for gram in range(2,16):
    print(f'Training ngram model for {gram=}')
    train_lm(gram)
    perplexity_with_OOVs, perplexity_without_OOVs, counts_of_OOVs = get_perplexity_and_OOVs(model_path=f"tnqeet/dotting_models/ngrams/trained_models/ngrams_{gram}.binary")
    print('*'*120)
    print(f"calculated perplexity for {gram=}")
    print('='*120)
    print(f'{perplexity_with_OOVs=}, {perplexity_without_OOVs=}, {counts_of_OOVs=}')
    print('='*120)
    print('*'*120)
# Out:
# Training ngram model for gram=2
# Language model for ngram 2 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:8688 kB	VmRSS:4512 kB	RSSMax:5248 kB	user:0.550673	sys:0.143653	CPU:0.694378	real:0.677878
# model name is: ngrams_2
# ************************************************************************************************************************
# calculated perplexity for gram=2
# ========================================================================================================================
# perplexity_with_OOVs=19.298962904664844, perplexity_without_OOVs=19.297093650302678, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=3
# Language model for ngram 3 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:13208 kB	VmRSS:4752 kB	RSSMax:10008 kB	user:0.609438	sys:0.14835	CPU:0.757852	real:0.743567
# model name is: ngrams_3
# ************************************************************************************************************************
# calculated perplexity for gram=3
# ========================================================================================================================
# perplexity_with_OOVs=13.435594232949741, perplexity_without_OOVs=13.434282116361908, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=4
# Language model for ngram 4 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:41532 kB	VmRSS:4424 kB	RSSMax:38004 kB	user:0.855188	sys:0.135871	CPU:0.991106	real:0.968091
# model name is: ngrams_4
# ************************************************************************************************************************
# calculated perplexity for gram=4
# ========================================================================================================================
# perplexity_with_OOVs=9.689946521066174, perplexity_without_OOVs=9.689078584416714, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=5
# Language model for ngram 5 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:171228 kB	VmRSS:4600 kB	RSSMax:167876 kB	user:1.30507	sys:0.168138	CPU:1.47328	real:1.44853
# model name is: ngrams_5
# ************************************************************************************************************************
# calculated perplexity for gram=5
# ========================================================================================================================
# perplexity_with_OOVs=7.983686983460504, perplexity_without_OOVs=7.982941215729369, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=6
# Language model for ngram 6 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:624832 kB	VmRSS:4588 kB	RSSMax:621468 kB	user:1.88882	sys:0.284123	CPU:2.17302	real:2.16751
# model name is: ngrams_6
# ************************************************************************************************************************
# calculated perplexity for gram=6
# ========================================================================================================================
# perplexity_with_OOVs=7.211993452486144, perplexity_without_OOVs=7.211306633237056, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=7
# Language model for ngram 7 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:1760516 kB	VmRSS:4624 kB	RSSMax:1757188 kB	user:2.40485	sys:0.487362	CPU:2.89229	real:2.88759
# model name is: ngrams_7
# ************************************************************************************************************************
# calculated perplexity for gram=7
# ========================================================================================================================
# perplexity_with_OOVs=6.754583692916848, perplexity_without_OOVs=6.753946468876465, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=8
# Language model for ngram 8 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:3845176 kB	VmRSS:4640 kB	RSSMax:3841864 kB	user:2.87631	sys:0.824089	CPU:3.70048	real:3.69568
# model name is: ngrams_8
# ************************************************************************************************************************
# calculated perplexity for gram=8
# ========================================================================================================================
# perplexity_with_OOVs=6.4405047995626, perplexity_without_OOVs=6.439892845315583, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=9
# Language model for ngram 9 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:6922332 kB	VmRSS:4480 kB	RSSMax:6918860 kB	user:2.83592	sys:1.43196	CPU:4.26792	real:4.26261
# model name is: ngrams_9
# ************************************************************************************************************************
# calculated perplexity for gram=9
# ========================================================================================================================
# perplexity_with_OOVs=6.2191120999520395, perplexity_without_OOVs=6.218516027916628, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=10
# Language model for ngram 10 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:10845928 kB	VmRSS:4412 kB	RSSMax:10842496 kB	user:3.17645	sys:1.90827	CPU:5.08481	real:5.07936
# model name is: ngrams_10
# ************************************************************************************************************************
# calculated perplexity for gram=10
# ========================================================================================================================
# perplexity_with_OOVs=6.078563378441161, perplexity_without_OOVs=6.077974917106491, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=11
# Language model for ngram 11 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:15393888 kB	VmRSS:4512 kB	RSSMax:15390448 kB	user:3.45217	sys:1.93209	CPU:5.38432	real:5.37951
# model name is: ngrams_11
# ************************************************************************************************************************
# calculated perplexity for gram=11
# ========================================================================================================================
# perplexity_with_OOVs=5.995941979643849, perplexity_without_OOVs=5.995357350508487, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=12
# Language model for ngram 12 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:20336352 kB	VmRSS:4372 kB	RSSMax:20332772 kB	user:3.64787	sys:2.39591	CPU:6.04385	real:6.03956
# model name is: ngrams_12
# ************************************************************************************************************************
# calculated perplexity for gram=12
# ========================================================================================================================
# perplexity_with_OOVs=5.945703844350016, perplexity_without_OOVs=5.945119485619699, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=13
# Language model for ngram 13 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:25470636 kB	VmRSS:4476 kB	RSSMax:25467160 kB	user:3.92513	sys:3.1369	CPU:7.06208	real:7.05679
# model name is: ngrams_13
# ************************************************************************************************************************
# calculated perplexity for gram=13
# ========================================================================================================================
# perplexity_with_OOVs=5.913868741561893, perplexity_without_OOVs=5.913286937797488, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=14
# Language model for ngram 14 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:30641280 kB	VmRSS:4424 kB	RSSMax:30637752 kB	user:4.12469	sys:2.82847	CPU:6.95319	real:6.9481
# model name is: ngrams_14
# ************************************************************************************************************************
# calculated perplexity for gram=14
# ========================================================================================================================
# perplexity_with_OOVs=5.893568848024322, perplexity_without_OOVs=5.892992515114622, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
# Training ngram model for gram=15
# Language model for ngram 15 already exists. Skipping training.
# This binary file contains probing hash tables.
# Name:query	VmPeak:35735436 kB	VmRSS:4564 kB	RSSMax:35732048 kB	user:3.95183	sys:4.82379	CPU:8.77569	real:8.75561
# model name is: ngrams_15
# ************************************************************************************************************************
# calculated perplexity for gram=15
# ========================================================================================================================
# perplexity_with_OOVs=5.879575022539873, perplexity_without_OOVs=5.878999768148102, counts_of_OOVs=24
# ========================================================================================================================
# ************************************************************************************************************************
