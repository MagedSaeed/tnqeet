# %%
from tnqeet.dotting_models.llms. models import OpenRouterArabicDotter
from tnqeet import remove_dots

# %%
dotter = OpenRouterArabicDotter(dspy_cache=False)
dotter

# %%
text = "أريد أن أتعلم البرمجة بلغة بايثون"
dotless_text = remove_dots(text)
text,dotless_text
# Out:
# ('أريد أن أتعلم البرمجة بلغة بايثون', 'ارٮد اں اٮعلم الٮرمحه ٮلعه ٮاٮٮوں')

# %%
restored_dotted_text =dotter.restore_dots(dotless_text)
restored_dotted_text
# Out:
# 'اريد ان اتعلم البرمجة بلغة بايثون'

# %%
dotter.lm.history[-1]
# Out:
# {'prompt': None,
#  'messages': [{'role': 'system',
# ...
